# %% [markdown]
# # 圖片資料

# %% [markdown]
# ## 0. 載入模組

# %%
import os
import torch
import numpy as np
import imageio as iio

# %%
# 圖片路徑：
image_path = "test_cat_image.jpg"

# 圖片資料夾路徑：
image_folder_path = "test_images"

# %% [markdown]
# ## 1. 載入圖片檔

# %%
img_arr = iio.v3.imread(image_path)
img_arr.shape
# Out:
# (3024, 4032, 3)

# %%
h, w, c = img_arr.shape
print("H(高度)：", h)
print("W(寬度)：", w)
print("C(色彩通道數)：", c)
# Out:
# H(高度)： 3024
# W(寬度)： 4032
# C(色彩通道數)： 3

# %% [markdown]
# $\star$ PyTorch 中要求圖片資料張量的軸順序為 **(C, H, W)**

# %% [markdown]
# ## 2. 調整張量各軸的排列順序

# %% [markdown]
# ### 2-1. 單張圖片

# %%
# 將 img_arr 轉成 PyTorch 張量：
img_arr = np.array(img_arr, copy=True)
img = torch.from_numpy(img_arr)

# 將第 2 軸移至第 0 軸，原本的第 0 軸及第 1 軸往後移：
new_img = img.permute(2, 0, 1)
new_img.shape
# Out:
# torch.Size([3, 3024, 4032])

# %% [markdown]
# ### 2-2. 多張圖片

# %%
# 查看圖片資料夾內圖片張數：
count_tmp = 0
for path in os.listdir(image_folder_path):
    if os.path.isfile(os.path.join(image_folder_path, path)):
        count_tmp += 1
print("圖片張數：", count_tmp)
# Out:
# 圖片張數： 4

# %%
# 設定一次可以載入 N 張圖片：
batch_size = count_tmp

# 設定張量可儲存 N 張高度 3024 與寬度 4032 像素的 RGB 圖片，並且設定每個顏色通道都能用 8 位元的正整數表示：
batch = torch.zeros(batch_size, 3, h, w, dtype=torch.uint8)

# %%
imgs_name = [name for name in os.listdir(image_folder_path) if os.path.splitext(name)[-1] == '.jpg']

for index, img_name in enumerate(imgs_name):
    img_arr = iio.v3.imread(os.path.join(image_folder_path, img_name))
    img_arr = np.array(img_arr, copy=True)
    img_t = torch.from_numpy(img_arr)
    img_t = img_t.permute(2, 0, 1)
    # 有些圖片會有表示透明度的第 3 軸，是我們不需要的，故只保留前面 3 軸 (H,W,C):
    img_t = img_t[:3]
    batch[index] = img_t
    
batch.shape
# Out:
# torch.Size([4, 3, 3024, 4032])

# %% [markdown]
# ## 3. 正規化（normalization）

# %% [markdown]
# $\star$ 像素值的範圍：**0～255**

# %% [markdown]
# ### 3-1. 直接除以 255

# %%
batch_1 = batch.float()
batch_1 /= 225.0

# %% [markdown]
# ### 3-2. 標準化

# %% [markdown]
# 計算輸入資料的**平均值**和**標準差**，並調整其大小，使每個色彩通道的平均值為 0 ，標準差為 1 。

# %%
# 取得色彩通道數量：
n_channels = batch.shape[1]

batch_2 = batch.float()
for c in range(n_channels):
    mean = torch.mean(batch_2[:, c])               # 計算平均值
    std = torch.std(batch_2[:, c])                 # 計算標準差
    batch_2[:, c] = (batch_2[:, c] - mean) / std   # 正規化

# %%
batch_2
# Out:
# tensor([[[[-0.3430, -0.3430, -0.3261,  ...,  0.4017,  0.4186,  0.4017],
#           [-0.3430, -0.3430, -0.3430,  ...,  0.4355,  0.4524,  0.4355],
#           [-0.3261, -0.3430, -0.3430,  ...,  0.5032,  0.5201,  0.4863],
#           ...,
#           [ 0.7232,  0.7232,  0.7401,  ...,  0.1309,  0.1478,  0.1478],
#           [ 0.7232,  0.7232,  0.7232,  ...,  0.1309,  0.1478,  0.1478],
#           [ 0.7232,  0.7232,  0.6894,  ...,  0.1309,  0.1478,  0.1478]],
#
#          [[-0.3067, -0.3067, -0.2888,  ...,  0.3733,  0.4090,  0.3912],
#           [-0.3067, -0.3067, -0.3067,  ...,  0.4090,  0.4448,  0.4269],
#           [-0.2888, -0.3067, -0.3067,  ...,  0.4806,  0.5164,  0.4806],
#           ...,
#           [ 1.0533,  1.0533,  1.0712,  ...,  0.1406,  0.1585,  0.1585],
#           [ 1.0533,  1.0533,  1.0533,  ...,  0.1406,  0.1585,  0.1585],
#           [ 1.0533,  1.0533,  1.0175,  ...,  0.1406,  0.1585,  0.1585]],
#
#          [[-0.1178, -0.1178, -0.0997,  ...,  0.4642,  0.4460,  0.4278],
#           [-0.1178, -0.1178, -0.1178,  ...,  0.5006,  0.4824,  0.4642],
#           [-0.0997, -0.1178, -0.1178,  ...,  0.5733,  0.5551,  0.5188],
#           ...,
#           [ 1.3191,  1.3191,  1.3373,  ...,  0.3733,  0.3914,  0.3914],
#           [ 1.3191,  1.3191,  1.3191,  ...,  0.3733,  0.3914,  0.3914],
#           [ 1.2827,  1.2827,  1.2463,  ...,  0.3733,  0.3914,  0.3914]]],
#
#
#         [[[-1.3246, -1.3246, -1.3077,  ..., -1.7477, -1.7647, -1.7816],
#           [-1.5277, -1.4939, -1.4770,  ..., -1.7308, -1.7477, -1.7647],
#           [-1.7477, -1.7139, -1.6631,  ..., -1.7139, -1.7139, -1.7139],
#           ...,
#           [ 0.8755,  0.8755,  0.8925,  ..., -0.2076, -0.2076, -0.2076],
#           [ 0.8586,  0.8755,  0.8755,  ..., -0.2076, -0.2076, -0.2076],
#           [ 0.8586,  0.8586,  0.8755,  ..., -0.1907, -0.2076, -0.2076]],
#
#          [[-1.2910, -1.2910, -1.2731,  ..., -1.7383, -1.7562, -1.7741],
#           [-1.5057, -1.4699, -1.4520,  ..., -1.7204, -1.7383, -1.7562],
#           [-1.7383, -1.7025, -1.6488,  ..., -1.7025, -1.7025, -1.7025],
#           ...,
#           [ 0.1764,  0.1764,  0.1943,  ..., -0.4499, -0.4499, -0.4499],
#           [ 0.1585,  0.1764,  0.1764,  ..., -0.4499, -0.4499, -0.4499],
#           [ 0.1585,  0.1585,  0.1764,  ..., -0.4320, -0.4499, -0.4499]],
#
#          [[-1.1182, -1.1182, -1.1000,  ..., -1.5729, -1.5911, -1.6093],
#           [-1.3365, -1.3001, -1.2819,  ..., -1.5548, -1.5729, -1.5911],
#           [-1.5729, -1.5366, -1.4820,  ..., -1.5366, -1.5366, -1.5366],
#           ...,
#           [-0.6635, -0.6635, -0.6453,  ..., -0.7181, -0.7181, -0.7181],
#           [-0.6817, -0.6635, -0.6635,  ..., -0.7181, -0.7181, -0.7181],
#           [-0.6817, -0.6817, -0.6635,  ..., -0.6999, -0.7181, -0.7181]]],
#
#
#         [[[-0.0553,  0.0124,  0.0801,  ..., -1.1554, -1.2062, -1.2231],
#           [-0.0215,  0.0462,  0.1309,  ..., -1.0200, -1.0538, -1.0708],
#           [-0.0215,  0.0462,  0.1478,  ..., -0.8169, -0.8338, -0.8338],
#           ...,
#           [-1.0538, -0.9861, -0.8677,  ..., -0.1738, -0.1568, -0.1738],
#           [-1.0369, -0.9692, -0.8677,  ..., -0.1568, -0.1399, -0.1568],
#           [-1.0877, -1.0200, -0.9184,  ..., -0.1738, -0.1568, -0.1738]],
#
#          [[-0.3425, -0.2710, -0.1994,  ..., -1.1120, -1.1299, -1.1478],
#           [-0.3067, -0.2352, -0.1457,  ..., -0.9688, -0.9688, -0.9867],
#           [-0.3067, -0.2352, -0.1278,  ..., -0.7541, -0.7362, -0.7362],
#           ...,
#           [-0.7183, -0.6467, -0.5215,  ...,  0.4448,  0.4627,  0.4448],
#           [-0.7004, -0.6288, -0.5215,  ...,  0.4448,  0.4627,  0.4448],
#           [-0.7541, -0.6825, -0.5752,  ...,  0.4269,  0.4448,  0.4269]],
#
#          [[-0.5544, -0.4816, -0.4089,  ..., -1.0818, -1.1182, -1.1546],
#           [-0.5180, -0.4452, -0.3543,  ..., -0.9363, -0.9545, -0.9727],
#           [-0.5180, -0.4452, -0.3361,  ..., -0.7181, -0.7181, -0.7181],
#           ...,
#           [-1.1728, -1.1000, -0.9363,  ...,  0.1186,  0.1368,  0.1186],
#           [-1.1546, -1.0818, -0.9727,  ...,  0.1186,  0.1368,  0.1186],
#           [-1.2092, -1.1364, -1.0273,  ...,  0.1004,  0.1186,  0.1004]]],
#
#
#         [[[-0.8000, -0.8169, -0.8338,  ...,  0.5709,  0.5709,  0.5540],
#           [-0.8338, -0.8338, -0.8507,  ...,  0.5709,  0.5709,  0.5540],
#           [-0.8507, -0.8677, -0.8846,  ...,  0.5709,  0.5709,  0.5709],
#           ...,
#           [ 0.7571,  0.7571,  0.7571,  ..., -0.3092, -0.3092, -0.3092],
#           [ 0.7571,  0.7571,  0.7571,  ..., -0.3092, -0.3092, -0.2922],
#           [ 0.7401,  0.7571,  0.7571,  ..., -0.3092, -0.2922, -0.2922]],
#
#          [[-0.6825, -0.7004, -0.7183,  ...,  0.7490,  0.7490,  0.7312],
#           [-0.7183, -0.7183, -0.7362,  ...,  0.7490,  0.7490,  0.7312],
#           [-0.7362, -0.7541, -0.7720,  ...,  0.7490,  0.7490,  0.7490],
#           ...,
#           [ 0.9638,  0.9638,  0.9638,  ..., -0.2888, -0.2888, -0.2888],
#           [ 0.9638,  0.9638,  0.9638,  ..., -0.2888, -0.2888, -0.2710],
#           [ 0.9459,  0.9638,  0.9638,  ..., -0.2888, -0.2710, -0.2710]],
#
#          [[-0.5180, -0.5362, -0.5544,  ...,  0.7916,  0.7916,  0.7734],
#           [-0.5544, -0.5544, -0.5726,  ...,  0.7916,  0.7916,  0.7734],
#           [-0.5726, -0.5907, -0.6089,  ...,  0.7916,  0.7916,  0.7916],
#           ...,
#           [ 1.1918,  1.1918,  1.1918,  ..., -0.2452, -0.2452, -0.2452],
#           [ 1.1918,  1.1918,  1.1918,  ..., -0.2452, -0.2452, -0.2270],
#           [ 1.1736,  1.1918,  1.1918,  ..., -0.2452, -0.2270, -0.2270]]]])
